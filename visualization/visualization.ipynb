# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
directory = os.getcwd()

# %%
files = os.listdir(directory + '\\data')
try:
    os.mkdir(os.mkdir(directory + '\\plots'))
except:
    pass
files
# Out:
# ['age.csv',
#  'ageHist.csv',
#  'ComplimentaryProducts.csv',
#  'DayDiff.csv',
#  'five_Orders_customers.csv',
#  'Pairs.csv',
#  'prices.csv',
#  'profitByProduct.csv',
#  'ProfitByTime.csv',
#  'ProfitByTimeCumulative.csv',
#  'Top5.csv']

# %%
for file in files:
    file_path = 'data\\' + file
    df_name = file[:-4]
    df = pd.read_csv(file_path)
    vars()[df_name] = df
    
    print(df_name)
    display(df)
# Out:
# age
#    median_age  mean_age  min_age  max_age
# 0          44        48       15       86
# ageHist
#     age_group  min_age  max_age  revenue_millions
# 0           1       15       19              2.55
# 1           2       19       23              2.68
# 2           3       23       27              2.62
# 3           4       27       31              2.50
# 4           5       31       34              2.45
# 5           6       34       38              2.46
# 6           7       38       41              2.45
# 7           8       41       44              2.47
# 8           9       44       49              2.02
# 9          10       49       54              1.87
# 10         11       54       60              1.80
# 11         12       60       65              1.82
# 12         13       65       70              1.79
# 13         14       70       76              1.81
# 14         15       76       81              1.86
# 15         16       81       86              1.85
# ComplimentaryProducts
#                  product_name  orders
# 0        USB-C Charging Cable    2212
# 1                      iPhone    2022
# 2            Wired Headphones    1859
# 3    Lightning Charging Cable    1851
# 4                Google Phone    1802
# 5    Apple Airpods Headphones    1011
# 6  Bose SoundSport Headphones     852
# 7      AAA Batteries (4-pack)     726
# 8       AA Batteries (4-pack)     707
# 9    Golf Handheld GPS Caddie     661
# DayDiff
#    avg_days_between_purchase  median_days_between_purchase
# 0                        112                            94
# five_Orders_customers
#    cnt_active_customers
# 0                   336
# Pairs
#                      product1                  product2  cnt_orders
# 0                      iPhone  Lightning Charging Cable        1015
# 1                Google Phone      USB-C Charging Cable         999
# 2                      iPhone          Wired Headphones         462
# 3                Google Phone          Wired Headphones         423
# 4    Apple Airpods Headphones                    iPhone         373
# 5    Golf Handheld GPS Caddie      USB-C Charging Cable         368
# 6  Bose SoundSport Headphones              Google Phone         228
# 7        USB-C Charging Cable          Wired Headphones         205
# 8    Golf Handheld GPS Caddie          Wired Headphones         149
# 9    Lightning Charging Cable          Wired Headphones         129
# prices
#                   product_name  product_price
# 0                 20in Monitor          99.99
# 1       27in 4K Gaming Monitor         359.99
# 2             27in FHD Monitor         109.00
# 3       34in Ultrawide Monitor         399.99
# 4        AA Batteries (4-pack)           4.29
# 5       AAA Batteries (4-pack)           2.89
# 6     Apple Airpods Headphones         139.00
# 7   Bose SoundSport Headphones         104.99
# 8                Flatscreen TV         250.00
# 9     Golf Handheld GPS Caddie         350.00
# 10                Google Phone         550.00
# 11                      iPhone         620.00
# 12                    LG Dryer         550.00
# 13          LG Washing Machine         495.00
# 14    Lightning Charging Cable          10.99
# 15          Macbook Pro Laptop        1649.00
# 16             ThinkPad Laptop         929.00
# 17        USB-C Charging Cable          10.99
# 18            Wired Headphones          11.99
# profitByProduct
#                   product_name  count_orders  total_revenue_million
# 0           Macbook Pro Laptop          4724                   8.25
# 1                       iPhone          6842                   4.54
# 2              ThinkPad Laptop          4128                   4.03
# 3                 Google Phone          5525                   3.29
# 4       34in Ultrawide Monitor          6181                   2.65
# 5     Apple Airpods Headphones         15549                   2.57
# 6       27in 4K Gaming Monitor          6230                   2.43
# 7   Bose SoundSport Headphones         13325                   1.64
# 8                Flatscreen TV          4800                   1.39
# 9             27in FHD Monitor          7507                   0.98
# 10    Golf Handheld GPS Caddie          2065                   0.81
# 11                20in Monitor          4101                   0.51
# 12                    LG Dryer           646                   0.39
# 13          LG Washing Machine           666                   0.37
# 14        USB-C Charging Cable         21903                   0.36
# 15    Lightning Charging Cable         21658                   0.32
# 16            Wired Headphones         18882                   0.27
# 17       AA Batteries (4-pack)         20577                   0.12
# 18      AAA Batteries (4-pack)         20641                   0.10
# ProfitByTime
#        y   m  count_orders  total_revenue_millions
# 0   2019   1          9675                    1.95
# 1   2019   2         11975                    2.36
# 2   2019   3         15153                    2.92
# 3   2019   4         18279                    3.41
# 4   2019   5         16566                    3.17
# 5   2019   6         13554                    2.70
# 6   2019   7         14293                    2.78
# 7   2019   8         11961                    2.37
# 8   2019   9         11621                    2.22
# 9   2019  10         20282                    3.66
# 10  2019  11         17573                    3.17
# 11  2019  12         24984                    4.29
# 12  2020   1            34                    0.01
# ProfitByTimeCumulative
#        y   m  count_orders  total_revenue_millions
# 0   2019   1          9675                    1.95
# 1   2019   2         21650                    4.31
# 2   2019   3         36803                    7.23
# 3   2019   4         55082                   10.64
# 4   2019   5         71648                   13.81
# 5   2019   6         85202                   16.51
# 6   2019   7         99495                   19.29
# 7   2019   8        111456                   21.66
# 8   2019   9        123077                   23.88
# 9   2019  10        143359                   27.54
# 10  2019  11        160932                   30.71
# 11  2019  12        185916                   35.00
# 12  2020   1        185950                   35.01
# Top5
#         cust_state              product_name  revenue_thousand  revenue_rank
# 0       California        Macbook Pro Laptop              3291             1
# 1       California                    iPhone              1844             2
# 2       California           ThinkPad Laptop              1565             3
# 3       California              Google Phone              1313             4
# 4       California    34in Ultrawide Monitor              1025             5
# 5    Georgia, U.S.        Macbook Pro Laptop               662             1
# 6    Georgia, U.S.                    iPhone               362             2
# 7    Georgia, U.S.           ThinkPad Laptop               348             3
# 8    Georgia, U.S.              Google Phone               268             4
# 9    Georgia, U.S.  Apple Airpods Headphones               208             5
# 10   Massachusetts        Macbook Pro Laptop              1941             1
# 11   Massachusetts                    iPhone              1093             2
# 12   Massachusetts           ThinkPad Laptop               976             3
# 13   Massachusetts              Google Phone               791             4
# 14   Massachusetts    34in Ultrawide Monitor               645             5
# 15  New York state        Macbook Pro Laptop              1145             1
# 16  New York state                    iPhone               584             2
# 17  New York state           ThinkPad Laptop               546             3
# 18  New York state              Google Phone               452             4
# 19  New York state    34in Ultrawide Monitor               370             5
# 20          Oregon        Macbook Pro Laptop               587             1
# 21          Oregon                    iPhone               299             2
# 22          Oregon           ThinkPad Laptop               267             3
# 23          Oregon              Google Phone               211             4
# 24          Oregon  Apple Airpods Headphones               181             5
# 25      Washington        Macbook Pro Laptop               620             1
# 26      Washington                    iPhone               362             2
# 27      Washington           ThinkPad Laptop               325             3
# 28      Washington              Google Phone               258             4
# 29      Washington    34in Ultrawide Monitor               229             5

# %%
prices = prices.sort_values(by='product_price')
profitByProduct = profitByProduct.sort_values(by='total_revenue_million')

# %%
fig, axs = plt.subplots(1, 2, sharey = True)
fig.set_size_inches(w=10, h=5)

ax = axs[0]
hbars = ax.barh(y=prices['product_name'], width=prices['product_price'])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.set_title('Цены')
ax.bar_label(hbars, fmt=lambda x: f'${x:.2f}')
ax.set_xticks([])

ax = axs[1]
hbars = ax.barh(y=profitByProduct['product_name'], width=profitByProduct['total_revenue_million'])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.set_title('Выручка')
ax.bar_label(hbars, fmt=lambda x: f'${x:.2f} млн.')
ax.set_xticks([])

plt.tight_layout()
plt.savefig(r'plots\prices_and_revenue.png')
plt.show()

# %%
top5_pivot = Top5.pivot(columns='product_name', index='cust_state', values='revenue_thousand').fillna(0)
top5_pivot.index.name = None
top5_pivot.columns.name = None
top5_pivot
# Out:
#                 34in Ultrawide Monitor  Apple Airpods Headphones  \
# California                      1025.0                       0.0
# Georgia, U.S.                      0.0                     208.0
# Massachusetts                    645.0                       0.0
# New York state                   370.0                       0.0
# Oregon                             0.0                     181.0
# Washington                       229.0                       0.0
#
#                 Google Phone  Macbook Pro Laptop  ThinkPad Laptop  iPhone
# California            1313.0              3291.0           1565.0  1844.0
# Georgia, U.S.          268.0               662.0            348.0   362.0
# Massachusetts          791.0              1941.0            976.0  1093.0
# New York state         452.0              1145.0            546.0   584.0
# Oregon                 211.0               587.0            267.0   299.0
# Washington             258.0               620.0            325.0   362.0

# %%
products = top5_pivot.columns.tolist()
products.sort(reverse=True, key=lambda x: top5_pivot[x].sum())
states = top5_pivot.index.tolist()

# %%
result = {}
for state in states:
    value = []
    sum = 0
    for product in products:
        current_value = top5_pivot.loc[state, product]
        value.append(current_value)
        sum += current_value
    result[state] = value/sum
result
# Out:
# {'California': array([0.36412923, 0.20402744, 0.17315778, 0.1452755 , 0.11341005,
#         0.        ]),
#  'Georgia, U.S.': array([0.35822511, 0.19588745, 0.18831169, 0.14502165, 0.        ,
#         0.11255411]),
#  'Massachusetts': array([0.35640837, 0.20069776, 0.1792141 , 0.14524422, 0.11843555,
#         0.        ]),
#  'New York state': array([0.36971263, 0.18856958, 0.17629964, 0.14594769, 0.11947046,
#         0.        ]),
#  'Oregon': array([0.37993528, 0.19352751, 0.17281553, 0.13656958, 0.        ,
#         0.1171521 ]),
#  'Washington': array([0.34559643, 0.20178372, 0.18115942, 0.14381271, 0.12764771,
#         0.        ])}

# %%
def survey(results, category_names):
    """
    Parameters
    ----------
    result : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = list(data[:, i])
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)     
        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, fmt = lambda x: f'{x*100:.2f}%' if x>0 else '', label_type='center', color=text_color)
    ax.legend(ncols=len(category_names) // 2, bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='small')

    return fig, ax

# %%
survey(result, products)
plt.title('Самые популярные товары в каждом штате', pad=50)
plt.tight_layout()
plt.savefig(r'plots\states.png')
plt.show()

# %%
Pairs['pair'] = Pairs['product1'] + ' +\n' + Pairs['product2'] 
Pairs = Pairs.sort_values(by='cnt_orders')
Pairs.head()
# Out:
#                      product1              product2  cnt_orders  \
# 9    Lightning Charging Cable      Wired Headphones         129
# 8    Golf Handheld GPS Caddie      Wired Headphones         149
# 7        USB-C Charging Cable      Wired Headphones         205
# 6  Bose SoundSport Headphones          Google Phone         228
# 5    Golf Handheld GPS Caddie  USB-C Charging Cable         368
#
#                                                pair
# 9      Lightning Charging Cable +\nWired Headphones
# 8      Golf Handheld GPS Caddie +\nWired Headphones
# 7          USB-C Charging Cable +\nWired Headphones
# 6        Bose SoundSport Headphones +\nGoogle Phone
# 5  Golf Handheld GPS Caddie +\nUSB-C Charging Cable

# %%
ComplimentaryProducts = ComplimentaryProducts.sort_values(by='orders')
ComplimentaryProducts.head()
# Out:
#                  product_name  orders
# 9    Golf Handheld GPS Caddie     661
# 8       AA Batteries (4-pack)     707
# 7      AAA Batteries (4-pack)     726
# 6  Bose SoundSport Headphones     852
# 5    Apple Airpods Headphones    1011

# %%
fig, axs = plt.subplots(1, 2)
fig.set_size_inches(w=10, h=5)

ax = axs[0]
hbars = ax.barh(y=Pairs['pair'], width=Pairs['cnt_orders'])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.set_title('Число заказов самых популярных пар товаров')
ax.bar_label(hbars)
ax.set_xticks([])

ax = axs[1]
hbars = ax.barh(y=ComplimentaryProducts['product_name'], width=ComplimentaryProducts['orders'])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.set_title('Число заказов товаров, которые часто покупаются\nв комлпекте с другими товарами')
ax.bar_label(hbars)
ax.set_xticks([])

plt.tight_layout()
plt.savefig(r'plots\pairs.png')
plt.show()

# %%
age
# Out:
#    median_age  mean_age  min_age  max_age
# 0          44        48       15       86

# %%
age_info_list = [f'Медианный возраст: {age["median_age"][0]}',
                 f'Средний возраст: {age["mean_age"][0]}',
                 f'Минимальный возраст: {age["min_age"][0]}',
                 f'Максимальный возраст: {age["max_age"][0]}']
age_info = '\n'.join(age_info_list)

# %%
age_info
# Out:
# 'Медианный возраст: 44\nСредний возраст: 48\nМинимальный возраст: 15\nМаксимальный возраст: 86'

# %%
DayDiff
# Out:
#    avg_days_between_purchase  median_days_between_purchase
# 0                        112                            94

# %%
day_diff_list = [f'Медианное число дней\nмежду покупками: {DayDiff["median_days_between_purchase"][0]}',
                 '\n',
                f'Среднее число дней\nмежду покупками: {DayDiff["avg_days_between_purchase"][0]}']
day_diff_info = '\n'.join(day_diff_list)

# %%
day_diff_info
# Out:
# 'Медианное число дней\nмежду покупками: 94\n\n\nСреднее число дней\nмежду покупками: 112'

# %%
five_Orders_customers
# Out:
#    cnt_active_customers
# 0                   336

# %%
most_active_customers = five_Orders_customers.values[0][0]

# %%
ageHist['min_age'] = ageHist.min_age.astype(str)
ageHist['max_age'] = ageHist.max_age.astype(str)
ageHist['age_bin'] = ageHist['min_age'] + '-' + ageHist['max_age']
ageHist.head()
# Out:
#    age_group min_age max_age  revenue_millions age_bin
# 0          1      15      19              2.55   15-19
# 1          2      19      23              2.68   19-23
# 2          3      23      27              2.62   23-27
# 3          4      27      31              2.50   27-31
# 4          5      31      34              2.45   31-34

# %%
fig, axs = plt.subplots(1, 2, width_ratios=[1, 3])
fig.set_size_inches(w=10, h=5)

ax = axs[0]
ax.axis('off')

ax.text(0.02, 0.7, age_info, fontsize=10, linespacing=1.5)
ax.text(0.02, 0.5, f'Число покупателей с 5 или\nболее заказами: {most_active_customers}', fontsize=10, linespacing=1.5)
ax.text(0.02, 0.1, day_diff_info, fontsize=10, linespacing=1.5)



ax = axs[1]
vbars = ax.bar(x=ageHist['age_bin'], height=ageHist['revenue_millions'], width=1, linewidth=0.5, edgecolor='black')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xticks(rotation=30)
ax.set_title('Распределение выручки в зависимости от возраста покупателей')
# ax.bar_label(vbars, fmt=lambda x: f'${x:.2f} млн.')

plt.tight_layout()
plt.savefig(r'plots\customers.png')
plt.show()

# %%
ProfitByTime['y'] = ProfitByTime.y.astype(str)
ProfitByTime['m'] = ProfitByTime.m.astype(str)
ProfitByTime['date'] = ProfitByTime.apply(lambda x: f"01-{x['m']:0>2}-{x['y']}", axis=1)
ProfitByTime['date'] = pd.to_datetime(ProfitByTime['date'], format="%d-%m-%Y")
ProfitByTime.dtypes
# Out:
# y                                 object
# m                                 object
# count_orders                       int64
# total_revenue_millions           float64
# date                      datetime64[ns]
# dtype: object

# %%
ProfitByTime.head()
# Out:
#       y  m  count_orders  total_revenue_millions       date
# 0  2019  1          9675                    1.95 2019-01-01
# 1  2019  2         11975                    2.36 2019-02-01
# 2  2019  3         15153                    2.92 2019-03-01
# 3  2019  4         18279                    3.41 2019-04-01
# 4  2019  5         16566                    3.17 2019-05-01

# %%
ProfitByTimeCumulative['y'] = ProfitByTimeCumulative.y.astype(str)
ProfitByTimeCumulative['m'] = ProfitByTimeCumulative.m.astype(str)
ProfitByTimeCumulative['date'] = ProfitByTimeCumulative.apply(lambda x: f"01-{x['m']:0>2}-{x['y']}", axis=1)
ProfitByTimeCumulative['date'] = pd.to_datetime(ProfitByTimeCumulative['date'], format="%d-%m-%Y")
ProfitByTime.dtypes
# Out:
# y                                 object
# m                                 object
# count_orders                       int64
# total_revenue_millions           float64
# date                      datetime64[ns]
# dtype: object

# %%
ProfitByTimeCumulative.head()
# Out:
#       y  m  count_orders  total_revenue_millions       date
# 0  2019  1          9675                    1.95 2019-01-01
# 1  2019  2         21650                    4.31 2019-02-01
# 2  2019  3         36803                    7.23 2019-03-01
# 3  2019  4         55082                   10.64 2019-04-01
# 4  2019  5         71648                   13.81 2019-05-01

# %%
fig, axs = plt.subplots(1, 2)
fig.set_size_inches(w=10, h=5)

ax = axs[0]

ax.plot(ProfitByTime['date'], ProfitByTime['total_revenue_millions'], label='Прибыль, $млн.')
ax.plot([], [], color='r', label='Число заказов')
ax1 = ax.twinx()
ax1.plot(ProfitByTime['date'], ProfitByTime['count_orders'], color='r')
ax.legend()

ax.set_title('Прибыль и число заказов от времени')
ax.tick_params(axis='x', rotation=45)


ax = axs[1]

ax.plot(ProfitByTimeCumulative['date'], ProfitByTimeCumulative['total_revenue_millions'], label='Прибыль, $млн.')
ax.plot([], [], color='r', label='Число заказов')
ax1 = ax.twinx()
ax1.plot(ProfitByTimeCumulative['date'], ProfitByTimeCumulative['count_orders'], color='r')
ax.legend()

ax.set_title('Накопительные прибыль и число заказов от времени')
ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig(r'plots\time_revenue.png')
plt.show()
